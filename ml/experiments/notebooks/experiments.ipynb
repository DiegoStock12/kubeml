# %% [markdown]
# # Testing the experiment classes

# %%
from common.experiment import KubemlExperiment, History, TrainOptions, TrainRequest
import pandas as pd
import glob
import numpy as np
import pickle

# %% [markdown]
# ## Merge experiments
#
# Get the small dataframes of each experiment and merge them onto a single dataframe

# %%
import glob
from typing import List

files = glob.glob('./tests/resnet34/*.pkl')

dataframes: List[pd.DataFrame] = []




for f in files:
    _d = pd.read_pickle(f)
    dataframes.append(_d)

d = pd.concat(dataframes, ignore_index=True)

d

d.to_pickle('resnet_36exp.pkl')

# %%
d.sort_values('epoch_duration', ascending=False)
# Out:
#           id model_type  batch_size  epochs  dataset   lr function_name  \
# 25  c205bf5c    example          32       1  cifar10  0.1        resnet
# 31  f1dd7b8d    example          32       1  cifar10  0.1        resnet
# 24  c087fe25    example         128       1  cifar10  0.1        resnet
# 9   56b29127    example          32       1  cifar10  0.1        resnet
# 15  8e062a4c    example          64       1  cifar10  0.1        resnet
# 16  8e3ac822    example          64       1  cifar10  0.1        resnet
# 26  cceb7cbe    example          64       1  cifar10  0.1        resnet
# 32  f302a8b3    example          32       1  cifar10  0.1        resnet
# 12  7eb2c57e    example          32       1  cifar10  0.1        resnet
# 5   38e2cee0    example          64       1  cifar10  0.1        resnet
# 35  f8819924    example          32       1  cifar10  0.1        resnet
# 6   3cb67a42    example          32       1  cifar10  0.1        resnet
# 14  8d265ab3    example          32       1  cifar10  0.1        resnet
# 18  97345e4e    example          32       1  cifar10  0.1        resnet
# 27  d584242d    example         128       1  cifar10  0.1        resnet
# 10  6019b966    example          32       1  cifar10  0.1        resnet
# 2   2aaa8a3d    example          32       1  cifar10  0.1        resnet
# 11  7b089a7b    example          32       1  cifar10  0.1        resnet
# 0   03da5d25    example         128       1  cifar10  0.1        resnet
# 34  f644866f    example          64       1  cifar10  0.1        resnet
# 21  a5e79e94    example          64       1  cifar10  0.1        resnet
# 23  bc355cce    example         128       1  cifar10  0.1        resnet
# 13  7f66ee7c    example          64       1  cifar10  0.1        resnet
# 19  993638f3    example         128       1  cifar10  0.1        resnet
# 17  91e12f01    example         128       1  cifar10  0.1        resnet
# 7   48989c6d    example          64       1  cifar10  0.1        resnet
# 4   350e0676    example          64       1  cifar10  0.1        resnet
# 3   2ec1758f    example          64       1  cifar10  0.1        resnet
# 28  d83ce6a3    example          64       1  cifar10  0.1        resnet
# 29  d891b5c4    example          64       1  cifar10  0.1        resnet
# 20  a306cc05    example         128       1  cifar10  0.1        resnet
# 33  f3c9c787    example         128       1  cifar10  0.1        resnet
# 22  a93afb72    example         128       1  cifar10  0.1        resnet
# 1   231943ff    example         128       1  cifar10  0.1        resnet
# 30  e8774533    example         128       1  cifar10  0.1        resnet
# 8   4cf3c3d1    example         128       1  cifar10  0.1        resnet
#
#     default_parallelism  static_parallelism  validate_every   k  \
# 25                    4                True               1   8
# 31                    4                True               1  64
# 24                    4                True               1   8
# 9                     8                True               1   8
# 15                    4                True               1   8
# 16                    8                True               1  16
# 26                    4                True               1  16
# 32                    4                True               1  16
# 12                    8                True               1  64
# 5                     4                True               1  64
# 35                   32                True               1  16
# 6                    32                True               1   8
# 14                   16                True               1   8
# 18                   16                True               1  16
# 27                    4                True               1  64
# 10                   16                True               1  64
# 2                    32                True               1  64
# 11                    8                True               1  16
# 0                     8                True               1   8
# 34                   16                True               1   8
# 21                    8                True               1   8
# 23                    8                True               1  16
# 13                   16                True               1  16
# 19                    8                True               1  64
# 17                    4                True               1  16
# 7                    16                True               1  64
# 4                    32                True               1  64
# 3                    32                True               1  16
# 28                    8                True               1  64
# 29                   32                True               1   8
# 20                   16                True               1   8
# 33                   16                True               1  16
# 22                   16                True               1  64
# 1                    32                True               1   8
# 30                   32                True               1  16
# 8                    32                True               1  64
#
#     goal_accuracy       validation_loss              accuracy  \
# 25            100  [1.7438390395892696]  [38.129999999999995]
# 31            100  [2.0665032189494124]               [19.93]
# 24            100  [1.8458453854428063]               [36.85]
# 9             100  [2.2803320846618553]                [31.3]
# 15            100  [1.7997186958410178]  [33.910000000000004]
# 16            100  [1.9520840933368464]               [28.18]
# 26            100  [1.8903891820057181]               [34.92]
# 32            100  [1.9263769814762444]               [27.21]
# 12            100  [2.2378345427040855]               [13.58]
# 5             100  [2.2510791660114458]               [12.67]
# 35            100  [2.4006100180811774]                  [10]
# 6             100   [2.176307292791982]               [21.16]
# 14            100  [2.6468114948120363]               [24.23]
# 18            100  [2.1531452786046477]               [18.87]
# 27            100  [2.4019780008098746]                  [10]
# 10            100  [2.3501257789782444]                  [10]
# 2             100   [6.456673442365262]                  [10]
# 11            100  [1.9803709736266457]  [26.369999999999997]
# 0             100  [1.9938284747208221]               [26.41]
# 34            100  [2.2232013022064403]               [13.23]
# 21            100  [1.8060335452389564]               [33.56]
# 23            100  [2.1183571604233755]               [19.18]
# 13            100   [2.314917175633133]               [10.22]
# 19            100    [2.99391896513444]                  [10]
# 17            100  [1.8563496523265597]                [32.9]
# 7             100   [6.321385304639294]                  [10]
# 4             100   [6.385458897633158]                  [10]
# 3             100   [4.153203514730855]                  [10]
# 28            100   [2.348529586366787]                  [10]
# 29            100  [3.5920156475844656]                  [10]
# 20            100   [2.505303313460531]               [12.04]
# 33            100  [2.6491925927657114]                  [10]
# 22            100   [4.762643234639228]                  [10]
# 1             100   [175.9012781457056]                  [10]
# 30            100  [4.1188574923744685]                  [10]
# 8             100  [3.2593925180314463]                  [10]
#
#               train_loss parallelism    epoch_duration
# 25  [2.8604170275129834]         [4]  [1146.221605277]
# 31   [3.179928240973857]         [4]  [1032.666816131]
# 24   [2.838177515623661]         [4]   [966.320484377]
# 9   [3.3851919494569302]         [8]   [886.874961812]
# 15   [3.118888764282068]         [4]   [848.364167759]
# 16   [4.047134656991277]         [8]    [844.06651628]
# 26  [3.1593298468356714]         [4]   [821.171543448]
# 32  [3.1147928775499265]         [4]   [816.765409495]
# 12   [4.056968173477799]         [8]   [813.481792294]
# 5   [3.3085530520183966]         [4]   [775.765169334]
# 35   [6.250339044219194]        [32]   [731.438649637]
# 6    [4.656333648366854]        [32]   [711.845770001]
# 14  [4.2458003268981415]        [16]   [699.765547291]
# 18  [4.7349645331524135]        [16]   [682.325691867]
# 27  [3.6382083398947382]         [4]   [654.697439909]
# 10   [5.990413401223961]        [16]   [647.651508903]
# 2    [8.465176700492991]        [32]   [628.306893289]
# 11  [3.8053046235671406]         [8]   [610.776431079]
# 0    [3.609585141763091]         [8]   [577.992817891]
# 34   [4.382735668548516]        [16]   [468.970774029]
# 21   [3.313504848629236]         [8]   [462.755352216]
# 23  [3.6921154379379004]         [8]   [444.576444607]
# 13   [4.402576372648279]        [16]   [441.476199527]
# 19   [4.684616235445957]         [8]   [433.159958355]
# 17  [2.9253751380102972]         [4]   [425.819621786]
# 7    [6.414901958138612]        [16]   [424.169764306]
# 4   [7.8308387949814415]        [32]   [415.313563337]
# 3    [5.782667923899782]        [32]   [414.973165487]
# 28   [4.230737259628919]         [8]   [400.757454297]
# 29   [6.230884659104049]        [32]   [396.080938403]
# 20   [4.690482895355672]        [16]   [340.314645023]
# 33   [4.912968591838661]        [16]   [297.962827092]
# 22   [5.533098703573147]        [16]   [281.368999286]
# 1    [6.146889317873865]        [32]     [255.3115073]
# 30   [6.713552589743182]        [32]   [235.325811442]
# 8    [6.321312318627649]        [32]   [231.404655465]

# %%
pd.read_pickle('./resnet_complete.pkl')

# %%
### Cifar100 dataset
# Out:
# c:\users\diego\cs\thesis\venv\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\diego\cs\thesis\venv\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# c:\users\diego\cs\thesis\venv\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [32, 64, 16, 16]          9,408
# ├─BatchNorm2d: 1-2                       [32, 64, 16, 16]          128
# ├─ReLU: 1-3                              [32, 64, 16, 16]          --
# ├─MaxPool2d: 1-4                         [32, 64, 8, 8]            --
# ├─Sequential: 1-5                        [32, 64, 8, 8]            --
# |    └─BasicBlock: 2-1                   [32, 64, 8, 8]            --
# |    |    └─Conv2d: 3-1                  [32, 64, 8, 8]            36,864
# |    |    └─BatchNorm2d: 3-2             [32, 64, 8, 8]            128
# |    |    └─ReLU: 3-3                    [32, 64, 8, 8]            --
# |    |    └─Conv2d: 3-4                  [32, 64, 8, 8]            36,864
# |    |    └─BatchNorm2d: 3-5             [32, 64, 8, 8]            128
# |    |    └─ReLU: 3-6                    [32, 64, 8, 8]            --
# |    └─BasicBlock: 2-2                   [32, 64, 8, 8]            --
# |    |    └─Conv2d: 3-7                  [32, 64, 8, 8]            36,864
# |    |    └─BatchNorm2d: 3-8             [32, 64, 8, 8]            128
# |    |    └─ReLU: 3-9                    [32, 64, 8, 8]            --
# |    |    └─Conv2d: 3-10                 [32, 64, 8, 8]            36,864
# |    |    └─BatchNorm2d: 3-11            [32, 64, 8, 8]            128
# |    |    └─ReLU: 3-12                   [32, 64, 8, 8]            --
# ├─Sequential: 1-6                        [32, 128, 4, 4]           --
# |    └─BasicBlock: 2-3                   [32, 128, 4, 4]           --
# |    |    └─Conv2d: 3-13                 [32, 128, 4, 4]           73,728
# |    |    └─BatchNorm2d: 3-14            [32, 128, 4, 4]           256
# |    |    └─ReLU: 3-15                   [32, 128, 4, 4]           --
# |    |    └─Conv2d: 3-16                 [32, 128, 4, 4]           147,456
# |    |    └─BatchNorm2d: 3-17            [32, 128, 4, 4]           256
# |    |    └─Sequential: 3-18             [32, 128, 4, 4]           8,448
# |    |    └─ReLU: 3-19                   [32, 128, 4, 4]           --
# |    └─BasicBlock: 2-4                   [32, 128, 4, 4]           --
# |    |    └─Conv2d: 3-20                 [32, 128, 4, 4]           147,456
# |    |    └─BatchNorm2d: 3-21            [32, 128, 4, 4]           256
# |    |    └─ReLU: 3-22                   [32, 128, 4, 4]           --
# |    |    └─Conv2d: 3-23                 [32, 128, 4, 4]           147,456
# |    |    └─BatchNorm2d: 3-24            [32, 128, 4, 4]           256
# |    |    └─ReLU: 3-25                   [32, 128, 4, 4]           --
# ├─Sequential: 1-7                        [32, 256, 2, 2]           --
# |    └─BasicBlock: 2-5                   [32, 256, 2, 2]           --
# |    |    └─Conv2d: 3-26                 [32, 256, 2, 2]           294,912
# |    |    └─BatchNorm2d: 3-27            [32, 256, 2, 2]           512
# |    |    └─ReLU: 3-28                   [32, 256, 2, 2]           --
# |    |    └─Conv2d: 3-29                 [32, 256, 2, 2]           589,824
# |    |    └─BatchNorm2d: 3-30            [32, 256, 2, 2]           512
# |    |    └─Sequential: 3-31             [32, 256, 2, 2]           33,280
# |    |    └─ReLU: 3-32                   [32, 256, 2, 2]           --
# |    └─BasicBlock: 2-6                   [32, 256, 2, 2]           --
# |    |    └─Conv2d: 3-33                 [32, 256, 2, 2]           589,824
# |    |    └─BatchNorm2d: 3-34            [32, 256, 2, 2]           512
# |    |    └─ReLU: 3-35                   [32, 256, 2, 2]           --
# |    |    └─Conv2d: 3-36                 [32, 256, 2, 2]           589,824
# |    |    └─BatchNorm2d: 3-37            [32, 256, 2, 2]           512
# |    |    └─ReLU: 3-38                   [32, 256, 2, 2]           --
# ├─Sequential: 1-8                        [32, 512, 1, 1]           --
# |    └─BasicBlock: 2-7                   [32, 512, 1, 1]           --
# |    |    └─Conv2d: 3-39                 [32, 512, 1, 1]           1,179,648
# |    |    └─BatchNorm2d: 3-40            [32, 512, 1, 1]           1,024
# |    |    └─ReLU: 3-41                   [32, 512, 1, 1]           --
# |    |    └─Conv2d: 3-42                 [32, 512, 1, 1]           2,359,296
# |    |    └─BatchNorm2d: 3-43            [32, 512, 1, 1]           1,024
# |    |    └─Sequential: 3-44             [32, 512, 1, 1]           132,096
# |    |    └─ReLU: 3-45                   [32, 512, 1, 1]           --
# |    └─BasicBlock: 2-8                   [32, 512, 1, 1]           --
# |    |    └─Conv2d: 3-46                 [32, 512, 1, 1]           2,359,296
# |    |    └─BatchNorm2d: 3-47            [32, 512, 1, 1]           1,024
# |    |    └─ReLU: 3-48                   [32, 512, 1, 1]           --
# |    |    └─Conv2d: 3-49                 [32, 512, 1, 1]           2,359,296
# |    |    └─BatchNorm2d: 3-50            [32, 512, 1, 1]           1,024
# |    |    └─ReLU: 3-51                   [32, 512, 1, 1]           --
# ├─AdaptiveAvgPool2d: 1-9                 [32, 512, 1, 1]           --
# ├─Linear: 1-10                           [32, 1000]                513,000
# ==========================================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# Total mult-adds (M): 60.03
# ==========================================================================================
# Input size (MB): 0.39
# Forward/backward pass size (MB): 26.21
# Params size (MB): 46.76
# Estimated Total Size (MB): 73.36
# ==========================================================================================

# %%
summary(r, input_size=(128, 3, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [128, 64, 16, 16]         9,408
# ├─BatchNorm2d: 1-2                       [128, 64, 16, 16]         128
# ├─ReLU: 1-3                              [128, 64, 16, 16]         --
# ├─MaxPool2d: 1-4                         [128, 64, 8, 8]           --
# ├─Sequential: 1-5                        [128, 64, 8, 8]           --
# |    └─BasicBlock: 2-1                   [128, 64, 8, 8]           --
# |    |    └─Conv2d: 3-1                  [128, 64, 8, 8]           36,864
# |    |    └─BatchNorm2d: 3-2             [128, 64, 8, 8]           128
# |    |    └─ReLU: 3-3                    [128, 64, 8, 8]           --
# |    |    └─Conv2d: 3-4                  [128, 64, 8, 8]           36,864
# |    |    └─BatchNorm2d: 3-5             [128, 64, 8, 8]           128
# |    |    └─ReLU: 3-6                    [128, 64, 8, 8]           --
# |    └─BasicBlock: 2-2                   [128, 64, 8, 8]           --
# |    |    └─Conv2d: 3-7                  [128, 64, 8, 8]           36,864
# |    |    └─BatchNorm2d: 3-8             [128, 64, 8, 8]           128
# |    |    └─ReLU: 3-9                    [128, 64, 8, 8]           --
# |    |    └─Conv2d: 3-10                 [128, 64, 8, 8]           36,864
# |    |    └─BatchNorm2d: 3-11            [128, 64, 8, 8]           128
# |    |    └─ReLU: 3-12                   [128, 64, 8, 8]           --
# ├─Sequential: 1-6                        [128, 128, 4, 4]          --
# |    └─BasicBlock: 2-3                   [128, 128, 4, 4]          --
# |    |    └─Conv2d: 3-13                 [128, 128, 4, 4]          73,728
# |    |    └─BatchNorm2d: 3-14            [128, 128, 4, 4]          256
# |    |    └─ReLU: 3-15                   [128, 128, 4, 4]          --
# |    |    └─Conv2d: 3-16                 [128, 128, 4, 4]          147,456
# |    |    └─BatchNorm2d: 3-17            [128, 128, 4, 4]          256
# |    |    └─Sequential: 3-18             [128, 128, 4, 4]          8,448
# |    |    └─ReLU: 3-19                   [128, 128, 4, 4]          --
# |    └─BasicBlock: 2-4                   [128, 128, 4, 4]          --
# |    |    └─Conv2d: 3-20                 [128, 128, 4, 4]          147,456
# |    |    └─BatchNorm2d: 3-21            [128, 128, 4, 4]          256
# |    |    └─ReLU: 3-22                   [128, 128, 4, 4]          --
# |    |    └─Conv2d: 3-23                 [128, 128, 4, 4]          147,456
# |    |    └─BatchNorm2d: 3-24            [128, 128, 4, 4]          256
# |    |    └─ReLU: 3-25                   [128, 128, 4, 4]          --
# ├─Sequential: 1-7                        [128, 256, 2, 2]          --
# |    └─BasicBlock: 2-5                   [128, 256, 2, 2]          --
# |    |    └─Conv2d: 3-26                 [128, 256, 2, 2]          294,912
# |    |    └─BatchNorm2d: 3-27            [128, 256, 2, 2]          512
# |    |    └─ReLU: 3-28                   [128, 256, 2, 2]          --
# |    |    └─Conv2d: 3-29                 [128, 256, 2, 2]          589,824
# |    |    └─BatchNorm2d: 3-30            [128, 256, 2, 2]          512
# |    |    └─Sequential: 3-31             [128, 256, 2, 2]          33,280
# |    |    └─ReLU: 3-32                   [128, 256, 2, 2]          --
# |    └─BasicBlock: 2-6                   [128, 256, 2, 2]          --
# |    |    └─Conv2d: 3-33                 [128, 256, 2, 2]          589,824
# |    |    └─BatchNorm2d: 3-34            [128, 256, 2, 2]          512
# |    |    └─ReLU: 3-35                   [128, 256, 2, 2]          --
# |    |    └─Conv2d: 3-36                 [128, 256, 2, 2]          589,824
# |    |    └─BatchNorm2d: 3-37            [128, 256, 2, 2]          512
# |    |    └─ReLU: 3-38                   [128, 256, 2, 2]          --
# ├─Sequential: 1-8                        [128, 512, 1, 1]          --
# |    └─BasicBlock: 2-7                   [128, 512, 1, 1]          --
# |    |    └─Conv2d: 3-39                 [128, 512, 1, 1]          1,179,648
# |    |    └─BatchNorm2d: 3-40            [128, 512, 1, 1]          1,024
# |    |    └─ReLU: 3-41                   [128, 512, 1, 1]          --
# |    |    └─Conv2d: 3-42                 [128, 512, 1, 1]          2,359,296
# |    |    └─BatchNorm2d: 3-43            [128, 512, 1, 1]          1,024
# |    |    └─Sequential: 3-44             [128, 512, 1, 1]          132,096
# |    |    └─ReLU: 3-45                   [128, 512, 1, 1]          --
# |    └─BasicBlock: 2-8                   [128, 512, 1, 1]          --
# |    |    └─Conv2d: 3-46                 [128, 512, 1, 1]          2,359,296
# |    |    └─BatchNorm2d: 3-47            [128, 512, 1, 1]          1,024
# |    |    └─ReLU: 3-48                   [128, 512, 1, 1]          --
# |    |    └─Conv2d: 3-49                 [128, 512, 1, 1]          2,359,296
# |    |    └─BatchNorm2d: 3-50            [128, 512, 1, 1]          1,024
# |    |    └─ReLU: 3-51                   [128, 512, 1, 1]          --
# ├─AdaptiveAvgPool2d: 1-9                 [128, 512, 1, 1]          --
# ├─Linear: 1-10                           [128, 1000]               513,000
# ==========================================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# Total mult-adds (M): 60.03
# ==========================================================================================
# Input size (MB): 1.57
# Forward/backward pass size (MB): 104.83
# Params size (MB): 46.76
# Estimated Total Size (MB): 153.16
# ==========================================================================================

# %%
r

# %%
from torchvision.models.vgg import vgg11

v = vgg11()
v

# %%
from torch import nn

class LeNet(nn.Module):
    """ Definition of the LeNet network as per the 1998 paper

    Credits to https://github.com/ChawDoe/LeNet5-MNIST-PyTorch for the
    convenience of the network definition and the train loop found there
    """

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(256, 120)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(120, 84)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(84, 10)
        self.relu5 = nn.ReLU()

    def forward(self, x):
        y = self.conv1(x)
        y = self.relu1(y)
        y = self.pool1(y)
        y = self.conv2(y)
        y = self.relu2(y)
        y = self.pool2(y)
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.relu3(y)
        y = self.fc2(y)
        y = self.relu4(y)
        y = self.fc3(y)
        y = self.relu5(y)
        return y

# %%
n = LeNet()
summary(n, input_size=(32, 1, 28, 28))
